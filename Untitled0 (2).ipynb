# %% [markdown]
# # Gym Members Exercise Dataset
# ## 1. Предобработка данных для датасета

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1.1 Загружаем датасет

# %%
df = pd.read_csv('gym_members_exercise_tracking.csv')

# %% [markdown]
# ## Информация о датафрейме

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 973 entries, 0 to 972
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            973 non-null    int64
#  1   Gender                         973 non-null    object
#  2   Weight (kg)                    973 non-null    float64
#  3   Height (m)                     973 non-null    float64
#  4   Max_BPM                        973 non-null    int64
#  5   Avg_BPM                        973 non-null    int64
#  6   Resting_BPM                    973 non-null    int64
#  7   Session_Duration (hours)       973 non-null    float64
#  8   Calories_Burned                973 non-null    float64
#  9   Workout_Type                   973 non-null    object
#  10  Fat_Percentage                 973 non-null    float64
#  11  Water_Intake (liters)          973 non-null    float64
# ...

# %% [markdown]
# ### В моем датасете 973 строки и 15 столбцов. Используются 13 числовых столбцов и 2 строковые. Пустых яцеек не найдено.
# ### Повезло 👍

# %% [markdown]
# #### 1.2 Выводим первые 5 строк

# %%
df.head()
# Out:
#    Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   56    Male         88.3        1.71      180      157           60
# 1   46  Female         74.9        1.53      179      151           66
# 2   32  Female         68.1        1.66      167      122           54
# 3   25    Male         53.2        1.70      190      164           56
# 4   38    Male         46.1        1.79      188      158           68
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      1.69           1313.0         Yoga            12.6
# 1                      1.30            883.0         HIIT            33.9
# 2                      1.11            677.0       Cardio            33.4
# 3                      0.59            532.0     Strength            28.8
# 4                      0.64            556.0     Strength            29.2
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# ...

# %% [markdown]
# ###Выводим последние 5 строк

# %%
df.tail()
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 968                      1.57           1364.0     Strength            10.0
# 969                      1.38           1260.0     Strength            25.0
# 970                      1.72            929.0       Cardio            18.8
# 971                      1.10            883.0         HIIT            28.2
# 972                      0.75            542.0     Strength            28.8
#
# ...

# %% [markdown]
# ### Случайная выборка 5 строк

# %%
df.sample(5)
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 659   42    Male         64.8        1.65      161      166           67
# 557   22    Male         86.2        1.90      186      128           58
# 27    59    Male         53.9        1.75      168      135           69
# 406   22    Male        102.1        1.85      190      157           67
# 860   23  Female         56.7        1.55      179      132           73
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 659                      1.10            904.0       Cardio            24.4
# 557                      1.91           1345.0     Strength            11.7
# 27                       1.48            989.0     Strength            21.6
# 406                      1.48           1278.0       Cardio            28.1
# 860                      1.38            911.0       Cardio            34.0
#
# ...

# %% [markdown]
# ### Атрибуты датафрейма

# %%
print('Форма датафрейма (строки и столбцы):', df.shape)
print('Название столбцов', list(df.columns))
# Out:
# Форма датафрейма (строки и столбцы): (973, 15)
# Название столбцов ['Age', 'Gender', 'Weight (kg)', 'Height (m)', 'Max_BPM', 'Avg_BPM', 'Resting_BPM', 'Session_Duration (hours)', 'Calories_Burned', 'Workout_Type', 'Fat_Percentage', 'Water_Intake (liters)', 'Workout_Frequency (days/week)', 'Experience_Level', 'BMI']

# %% [markdown]
# ### Использование памяти

# %%
df.memory_usage(deep=True)
# Out:
# Index                              132
# Age                               7784
# Gender                           60277
# Weight (kg)                       7784
# Height (m)                        7784
# Max_BPM                           7784
# Avg_BPM                           7784
# Resting_BPM                       7784
# Session_Duration (hours)          7784
# Calories_Burned                   7784
# Workout_Type                     60895
# Fat_Percentage                    7784
# Water_Intake (liters)             7784
# Workout_Frequency (days/week)     7784
# Experience_Level                  7784
# BMI                               7784
# dtype: int64

# %% [markdown]
# ### 2.1 Выявление проблемных в данных

# %%
# Получим описательную статистику по числовым и категориальным столбцам
print('Описательная статистика(числовае столбцы):')
print(df.describe())
print('Описательная статистика(все столбцы):')
print(df.describe(include='all'))

# Проверим уникальные значения для категориальных признаков
print('\nУникальные значения для категориальных столбцов:')
for col in df.select_dtypes(include='object').columns:
  print(f'{col}:', df[col].unique()[:15]) # первые 15 ункальных значений
# Out:
# Описательная статистика(числовае столбцы):
#               Age  Weight (kg)  Height (m)     Max_BPM     Avg_BPM  \
# count  973.000000   973.000000   973.00000  973.000000  973.000000
# mean    38.683453    73.854676     1.72258  179.883864  143.766701
# std     12.180928    21.207500     0.12772   11.525686   14.345101
# min     18.000000    40.000000     1.50000  160.000000  120.000000
# 25%     28.000000    58.100000     1.62000  170.000000  131.000000
# 50%     40.000000    70.000000     1.71000  180.000000  143.000000
# 75%     49.000000    86.000000     1.80000  190.000000  156.000000
# max     59.000000   129.900000     2.00000  199.000000  169.000000
#
#        Resting_BPM  Session_Duration (hours)  Calories_Burned  Fat_Percentage  \
# count   973.000000                973.000000       973.000000      973.000000
# mean     62.223022                  1.256423       905.422405       24.976773
# std       7.327060                  0.343033       272.641516        6.259419
# ...

# %% [markdown]
# ### 3. Проверка и приведение наименований столбцов и текста к нижнему регистру
# ### Приведём названия столбцов к змеиному регистру (snake_case) и нижнему регистру
# ### Приведём все текстовые значения к нижнему регистру

# %%
print('\nПреобразуем названия столбцов к змеиному регистру и нижнему регистру:')
df.columns = [col.strip().replace(' ', '_').replace('-', '_').lower() for col in df.columns]
df.columns = df.columns.str.replace('(', '', regex=False).str.replace(')', '', regex=False)
print('Новые названия столбцов:', list(df.columns))

for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].str.lower()
print('Все текстовые значения приведены к нижнему регистру.')
# Out:
# Преобразуем названия столбцов к змеиному регистру и нижнему регистру:
# Новые названия столбцов: ['age', 'gender', 'weight_kg', 'height_m', 'max_bpm', 'avg_bpm', 'resting_bpm', 'session_duration_hours', 'calories_burned', 'workout_type', 'fat_percentage', 'water_intake_liters', 'workout_frequency_days/week', 'experience_level', 'bmi']
# Все текстовые значения приведены к нижнему регистру.

# %% [markdown]
# ### Проверьте датафрейм на пропуски. Заполните пропущенные значения.
# Для каждой замены укажите, почему пропущенные значения заполняются именно
# таким образом. (NB! Если строки с пропусками составляют не более 5% от
# общего числа строк и заполнить их не представляется возможным, в этом случае
# строки можно удалить).

# %%
# 1. ПРОПУСКИ
nulls_per_col = df.isna().sum()
total_nulls   = nulls_per_col.sum()       # всего пропусков
print(nulls_per_col)
print(f'Всего пропусков: {total_nulls}')

# 2. ПОЛНЫЕ ДУБЛИКАТЫ СТРОК
dup_rows = df.duplicated().sum()
print(f'Полных дубликатов строк: {dup_rows}')
# Out:
# age                            0
# gender                         0
# weight_kg                      0
# height_m                       0
# max_bpm                        0
# avg_bpm                        0
# resting_bpm                    0
# session_duration_hours         0
# calories_burned                0
# workout_type                   0
# fat_percentage                 0
# water_intake_liters            0
# workout_frequency_days/week    0
# experience_level               0
# bmi                            0
# dtype: int64
# Всего пропусков: 0
# Полных дубликатов строк: 0

# %% [markdown]
# # 5. Изменение типов данных
# Изменение типов данных не было произведено по причине того что данный датасет полностью устраивает данной бизнес задаче

# %% [markdown]
# ### Промежуточные выводы
# В датафрейме небыло найдено пропусков и дубликатов.Также все названия столбцов были приведены к змеиному регистру (snake_case) и нижнему регистру.Были убраны и заменены пробелы и скобки в названии столбцов.
# ### Запустите ячейку нижу чтобы убиветь итог данной работы.
# ### #Чтобы запустить нажмите на эту кнопку ▶

# %%
print(f'Итоговая форма датафрейма: {df.shape}')
print('Типы данных после обработки:')
print(df.dtypes)
print('Количество пропусков после обработки:')
print(df.isnull().sum().sum())
print('Предобработка завершена.')
# Out:
# Итоговая форма датафрейма: (973, 15)
# Типы данных после обработки:
# age                              int64
# gender                          object
# weight_kg                      float64
# height_m                       float64
# max_bpm                          int64
# avg_bpm                          int64
# resting_bpm                      int64
# session_duration_hours         float64
# calories_burned                float64
# workout_type                    object
# fat_percentage                 float64
# water_intake_liters            float64
# workout_frequency_days/week      int64
# experience_level                 int64
# bmi                            float64
# dtype: object
# Количество пропусков после обработки:
# 0
# Предобработка завершена.

# %% [markdown]
# ## 2. Исследовательский анализ данных

# %% [markdown]
# ### Индексация по координатам

# %%
df.iloc[:5]
# Out:
#    age  gender  weight_kg  height_m  max_bpm  avg_bpm  resting_bpm  \
# 0   56    male       88.3      1.71      180      157           60
# 1   46  female       74.9      1.53      179      151           66
# 2   32  female       68.1      1.66      167      122           54
# 3   25    male       53.2      1.70      190      164           56
# 4   38    male       46.1      1.79      188      158           68
#
#    session_duration_hours  calories_burned workout_type  fat_percentage  \
# 0                    1.69           1313.0         yoga            12.6
# 1                    1.30            883.0         hiit            33.9
# 2                    1.11            677.0       cardio            33.4
# 3                    0.59            532.0     strength            28.8
# 4                    0.64            556.0     strength            29.2
#
#    water_intake_liters  workout_frequency_days/week  experience_level    bmi
# ...

# %%
df.loc[:9,['gender','age']]
# Out:
#    gender  age
# 0    male   56
# 1  female   46
# 2  female   32
# 3    male   25
# 4    male   38
# 5  female   56
# 6    male   36
# 7  female   40
# 8    male   28
# 9    male   28

# %%
df.iloc[:,0:4]
# Out:
#      age  gender  weight_kg  height_m
# 0     56    male       88.3      1.71
# 1     46  female       74.9      1.53
# 2     32  female       68.1      1.66
# 3     25    male       53.2      1.70
# 4     38    male       46.1      1.79
# ..   ...     ...        ...       ...
# 968   24    male       87.1      1.74
# 969   25    male       66.6      1.61
# 970   59  female       60.4      1.76
# 971   32    male      126.4      1.83
# 972   46    male       88.7      1.63
#
# [973 rows x 4 columns]

# %%
df.loc[100:105, ['weight_kg','height_m']]
# Out:
#      weight_kg  height_m
# 100       77.7      1.62
# 101       41.2      1.62
# 102       58.6      1.61
# 103      109.3      1.78
# 104       69.6      1.96
# 105       56.2      1.79

# %%
df.iloc[-5:,-3:]
# Out:
#      workout_frequency_days/week  experience_level    bmi
# 968                            4                 3  28.77
# 969                            2                 1  25.69
# 970                            5                 3  19.50
# 971                            3                 2  37.74
# 972                            2                 1  33.38

# %% [markdown]
# ### Логическая индексация

# %%
df[df['age']>50]
# Out:
#      age  gender  weight_kg  height_m  max_bpm  avg_bpm  resting_bpm  \
# 0     56    male       88.3      1.71      180      157           60
# 5     56  female       58.0      1.68      168      156           74
# 11    53    male       51.7      1.70      175      152           72
# 12    57    male      112.5      1.61      195      165           61
# 19    55  female       75.2      1.67      188      167           51
# ..   ...     ...        ...       ...      ...      ...          ...
# 952   55    male       69.9      1.81      179      167           57
# 962   57    male       83.4      1.65      172      166           67
# 963   57  female       43.8      1.75      180      160           73
# 964   56  female       64.2      1.69      190      137           61
# 970   59  female       60.4      1.76      194      120           53
#
#      session_duration_hours  calories_burned workout_type  fat_percentage  \
# ...

# %%
df[(df['gender']=='female')&(df['workout_type']=='yoga')]
# Out:
#      age  gender  weight_kg  height_m  max_bpm  avg_bpm  resting_bpm  \
# 22    50  female       71.0      1.68      187      161           70
# 25    42  female       63.7      1.71      173      169           62
# 31    20  female       65.4      1.52      185      127           50
# 50    34  female       51.0      1.62      162      158           53
# 56    59  female       65.5      1.52      161      162           61
# ..   ...     ...        ...       ...      ...      ...          ...
# 921   29  female       75.6      1.80      175      149           57
# 950   31  female       76.7      1.62      174      127           74
# 953   50  female       67.9      1.77      171      164           73
# 961   31  female       66.6      1.67      184      137           71
# 965   23  female       44.1      1.62      196      122           58
#
#      session_duration_hours  calories_burned workout_type  fat_percentage  \
# ...

# %%
df[df['experience_level']>2]
# Out:
#      age  gender  weight_kg  height_m  max_bpm  avg_bpm  resting_bpm  \
# 0     56    male       88.3      1.71      180      157           60
# 5     56  female       58.0      1.68      168      156           74
# 28    45    male       84.9      1.86      186      136           66
# 34    38    male       81.4      1.71      187      148           58
# 51    53    male       84.2      1.76      165      137           69
# ..   ...     ...        ...       ...      ...      ...          ...
# 962   57    male       83.4      1.65      172      166           67
# 964   56  female       64.2      1.69      190      137           61
# 966   23    male       87.3      1.91      164      129           58
# 968   24    male       87.1      1.74      187      158           67
# 970   59  female       60.4      1.76      194      120           53
#
#      session_duration_hours  calories_burned workout_type  fat_percentage  \
# ...

# %%
df[df['calories_burned']>1500]
# Out:
#      age  gender  weight_kg  height_m  max_bpm  avg_bpm  resting_bpm  \
# 66    32    male       85.9      1.60      176      145           60
# 90    25    male       81.5      1.61      170      159           63
# 99    24  female       60.1      1.79      170      165           63
# 124   26    male       86.2      1.68      189      157           72
# 132   49    male       82.8      1.95      183      159           73
# 391   43    male       82.9      1.95      181      160           70
# 475   27    male       89.3      1.64      192      162           64
# 511   39    male       86.2      1.82      191      160           72
# 572   36    male       88.0      1.71      185      160           73
# 587   18    male       83.2      1.96      183      150           67
# 646   22    male       88.5      1.62      174      162           69
# 649   27    male       88.5      1.98      161      153           53
# 712   19    male       82.4      1.96      174      169           62
# ...

# %%
df[(df['height_m']>1.85)&(df['resting_bpm']<60)]
# Out:
#      age gender  weight_kg  height_m  max_bpm  avg_bpm  resting_bpm  \
# 8     28   male      121.7      1.94      185      127           52
# 52    57   male      122.1      1.89      165      134           58
# 106   41   male       71.7      1.96      162      168           51
# 107   54   male       86.0      1.93      171      163           51
# 117   20   male       82.7      1.99      179      146           59
# ..   ...    ...        ...       ...      ...      ...          ...
# 892   20   male       85.7      1.92      172      136           58
# 908   26   male       51.9      2.00      173      133           54
# 926   39   male      102.3      1.94      192      134           50
# 954   40   male       87.9      1.87      196      134           54
# 966   23   male       87.3      1.91      164      129           58
#
#      session_duration_hours  calories_burned workout_type  fat_percentage  \
# 8                      1.03            719.0     strength            28.9
# ...

# %% [markdown]
# ### Сортировка данных и анализ

# %%
df.sort_values(by = 'age').head()
# Out:
#      age  gender  weight_kg  height_m  max_bpm  avg_bpm  resting_bpm  \
# 771   18  female       57.2      1.75      193      160           74
# 85    18  female       54.8      1.68      176      158           71
# 884   18    male      114.5      1.97      192      128           60
# 353   18  female       72.7      1.55      172      125           56
# 80    18  female       52.3      1.74      187      165           58
#
#      session_duration_hours  calories_burned workout_type  fat_percentage  \
# 771                    1.29           1032.0       cardio            33.5
# 85                     1.27           1003.0     strength            32.0
# 884                    1.03            725.0       cardio            24.1
# 353                    0.84            525.0       cardio            29.8
# 80                     1.20            990.0       cardio            29.4
#
#      water_intake_liters  workout_frequency_days/week  experience_level    bmi
# ...

# %%
df.sort_values(by = 'calories_burned', ascending=False).head()
# Out:
#      age gender  weight_kg  height_m  max_bpm  avg_bpm  resting_bpm  \
# 910   32   male       89.8      1.92      199      168           67
# 712   19   male       82.4      1.96      174      169           62
# 511   39   male       86.2      1.82      191      160           72
# 124   26   male       86.2      1.68      189      157           72
# 90    25   male       81.5      1.61      170      159           63
#
#      session_duration_hours  calories_burned workout_type  fat_percentage  \
# 910                    1.93           1783.0     strength            10.6
# 712                    1.90           1766.0         hiit            10.1
# 511                    1.96           1725.0     strength            10.2
# 124                    1.97           1701.0     strength            13.3
# 90                     1.93           1688.0         hiit            10.9
#
#      water_intake_liters  workout_frequency_days/week  experience_level    bmi
# ...

# %%
df.sort_values(by='bmi').head() #наименьший
# Out:
#      age  gender  weight_kg  height_m  max_bpm  avg_bpm  resting_bpm  \
# 783   47    male       45.9      1.93      166      159           65
# 156   56  female       40.4      1.80      196      165           72
# 425   38  female       40.6      1.79      195      161           55
# 258   25    male       49.9      1.98      165      122           68
# 747   33    male       45.9      1.89      193      144           50
#
#      session_duration_hours  calories_burned workout_type  fat_percentage  \
# 783                    1.29           1015.0       cardio            29.6
# 156                    1.23            913.0       cardio            30.0
# 425                    0.62            499.0       cardio            26.8
# 258                    1.15            772.0         yoga            25.7
# 747                    1.45           1148.0       cardio            21.6
#
#      water_intake_liters  workout_frequency_days/week  experience_level    bmi
# ...

# %%
df.sort_values(by='bmi', ascending=False).head()#наибольший
# Out:
#      age gender  weight_kg  height_m  max_bpm  avg_bpm  resting_bpm  \
# 854   48   male      129.2      1.61      193      167           62
# 945   35   male      127.1      1.62      187      128           69
# 261   57   male      126.8      1.63      161      133           73
# 710   38   male      123.3      1.62      161      165           65
# 868   47   male      127.8      1.65      198      157           60
#
#      session_duration_hours  calories_burned workout_type  fat_percentage  \
# 854                    1.06            876.0         yoga            21.4
# 945                    1.02            718.0     strength            23.3
# 261                    0.96            632.0         yoga            20.8
# 710                    1.34           1216.0         yoga            21.2
# 868                    0.77            598.0       cardio            28.7
#
#      water_intake_liters  workout_frequency_days/week  experience_level    bmi
# ...

# %%
df.sort_values(by='workout_type', ascending=False).head()
# Out:
#      age  gender  weight_kg  height_m  max_bpm  avg_bpm  resting_bpm  \
# 0     56    male       88.3      1.71      180      157           60
# 471   43  female       73.0      1.59      191      158           67
# 513   36    male       85.4      1.88      195      137           60
# 510   42    male       63.7      1.98      172      128           69
# 508   34    male       65.9      1.62      199      164           56
#
#      session_duration_hours  calories_burned workout_type  fat_percentage  \
# 0                      1.69           1313.0         yoga            12.6
# 471                    1.31            931.0         yoga            28.9
# 513                    1.98           1492.0         yoga            13.5
# 510                    1.37            868.0         yoga            24.0
# 508                    0.81            731.0         yoga            28.8
#
#      water_intake_liters  workout_frequency_days/week  experience_level    bmi
# ...

# %% [markdown]
# ### Метод query

# %%
df.query("gender == 'male'")
# Out:
#      age gender  weight_kg  height_m  max_bpm  avg_bpm  resting_bpm  \
# 0     56   male       88.3      1.71      180      157           60
# 3     25   male       53.2      1.70      190      164           56
# 4     38   male       46.1      1.79      188      158           68
# 6     36   male       70.3      1.72      174      169           73
# 8     28   male      121.7      1.94      185      127           52
# ..   ...    ...        ...       ...      ...      ...          ...
# 967   20   male       55.0      1.60      172      168           67
# 968   24   male       87.1      1.74      187      158           67
# 969   25   male       66.6      1.61      184      166           56
# 971   32   male      126.4      1.83      198      146           62
# 972   46   male       88.7      1.63      166      146           66
#
#      session_duration_hours  calories_burned workout_type  fat_percentage  \
# 0                      1.69           1313.0         yoga            12.6
# ...

# %%
df.query('age > 33')
# Out:
#      age  gender  weight_kg  height_m  max_bpm  avg_bpm  resting_bpm  \
# 0     56    male       88.3      1.71      180      157           60
# 1     46  female       74.9      1.53      179      151           66
# 4     38    male       46.1      1.79      188      158           68
# 5     56  female       58.0      1.68      168      156           74
# 6     36    male       70.3      1.72      174      169           73
# ..   ...     ...        ...       ...      ...      ...          ...
# 962   57    male       83.4      1.65      172      166           67
# 963   57  female       43.8      1.75      180      160           73
# 964   56  female       64.2      1.69      190      137           61
# 970   59  female       60.4      1.76      194      120           53
# 972   46    male       88.7      1.63      166      146           66
#
#      session_duration_hours  calories_burned workout_type  fat_percentage  \
# ...

# %%
df.query("session_duration_hours > 1.2")
# Out:
#      age  gender  weight_kg  height_m  max_bpm  avg_bpm  resting_bpm  \
# 0     56    male       88.3      1.71      180      157           60
# 1     46  female       74.9      1.53      179      151           66
# 5     56  female       58.0      1.68      168      156           74
# 6     36    male       70.3      1.72      174      169           73
# 7     40  female       69.7      1.51      189      141           64
# ..   ...     ...        ...       ...      ...      ...          ...
# 964   56  female       64.2      1.69      190      137           61
# 966   23    male       87.3      1.91      164      129           58
# 968   24    male       87.1      1.74      187      158           67
# 969   25    male       66.6      1.61      184      166           56
# 970   59  female       60.4      1.76      194      120           53
#
#      session_duration_hours  calories_burned workout_type  fat_percentage  \
# ...

# %%
df.query("calories_burned > 1111")
# Out:
#      age  gender  weight_kg  height_m  max_bpm  avg_bpm  resting_bpm  \
# 0     56    male       88.3      1.71      180      157           60
# 5     56  female       58.0      1.68      168      156           74
# 6     36    male       70.3      1.72      174      169           73
# 14    20    male      117.7      1.81      196      161           54
# 34    38    male       81.4      1.71      187      148           58
# ..   ...     ...        ...       ...      ...      ...          ...
# 962   57    male       83.4      1.65      172      166           67
# 964   56  female       64.2      1.69      190      137           61
# 966   23    male       87.3      1.91      164      129           58
# 968   24    male       87.1      1.74      187      158           67
# 969   25    male       66.6      1.61      184      166           56
#
#      session_duration_hours  calories_burned workout_type  fat_percentage  \
# ...

# %%
df.query("gender == 'male' and weight_kg > 79 and workout_type =='hiit'")
# Out:
#      age gender  weight_kg  height_m  max_bpm  avg_bpm  resting_bpm  \
# 10    41   male      120.8      1.67      188      146           54
# 13    41   male       94.5      2.00      179      136           69
# 28    45   male       84.9      1.86      186      136           66
# 30    32   male      108.2      1.80      172      138           53
# 34    38   male       81.4      1.71      187      148           58
# ..   ...    ...        ...       ...      ...      ...          ...
# 936   54   male      117.2      1.62      172      143           56
# 942   42   male       86.3      1.77      172      127           55
# 962   57   male       83.4      1.65      172      166           67
# 966   23   male       87.3      1.91      164      129           58
# 971   32   male      126.4      1.83      198      146           62
#
#      session_duration_hours  calories_burned workout_type  fat_percentage  \
# 10                     0.82            593.0         hiit            20.5
# ...

# %% [markdown]
# ### Oператор np.where

# %%
show = df.where(df['age'] > 30).dropna(how = 'all')
show
# Out:
#       age  gender  weight_kg  height_m  max_bpm  avg_bpm  resting_bpm  \
# 0    56.0    male       88.3      1.71    180.0    157.0         60.0
# 1    46.0  female       74.9      1.53    179.0    151.0         66.0
# 2    32.0  female       68.1      1.66    167.0    122.0         54.0
# 4    38.0    male       46.1      1.79    188.0    158.0         68.0
# 5    56.0  female       58.0      1.68    168.0    156.0         74.0
# ..    ...     ...        ...       ...      ...      ...          ...
# 963  57.0  female       43.8      1.75    180.0    160.0         73.0
# 964  56.0  female       64.2      1.69    190.0    137.0         61.0
# 970  59.0  female       60.4      1.76    194.0    120.0         53.0
# 971  32.0    male      126.4      1.83    198.0    146.0         62.0
# 972  46.0    male       88.7      1.63    166.0    146.0         66.0
#
#      session_duration_hours  calories_burned workout_type  fat_percentage  \
# ...

# %%
show = df.where(df['gender'] == 'male').dropna(how = 'all')
show
# Out:
#       age gender  weight_kg  height_m  max_bpm  avg_bpm  resting_bpm  \
# 0    56.0   male       88.3      1.71    180.0    157.0         60.0
# 3    25.0   male       53.2      1.70    190.0    164.0         56.0
# 4    38.0   male       46.1      1.79    188.0    158.0         68.0
# 6    36.0   male       70.3      1.72    174.0    169.0         73.0
# 8    28.0   male      121.7      1.94    185.0    127.0         52.0
# ..    ...    ...        ...       ...      ...      ...          ...
# 967  20.0   male       55.0      1.60    172.0    168.0         67.0
# 968  24.0   male       87.1      1.74    187.0    158.0         67.0
# 969  25.0   male       66.6      1.61    184.0    166.0         56.0
# 971  32.0   male      126.4      1.83    198.0    146.0         62.0
# 972  46.0   male       88.7      1.63    166.0    146.0         66.0
#
#      session_duration_hours  calories_burned workout_type  fat_percentage  \
# ...

# %%
show = df.where((df['gender'] == 'male') & (df['weight_kg'] > 79)).dropna(how = 'all')
show
# Out:
#       age gender  weight_kg  height_m  max_bpm  avg_bpm  resting_bpm  \
# 0    56.0   male       88.3      1.71    180.0    157.0         60.0
# 8    28.0   male      121.7      1.94    185.0    127.0         52.0
# 9    28.0   male      101.8      1.84    169.0    136.0         64.0
# 10   41.0   male      120.8      1.67    188.0    146.0         54.0
# 12   57.0   male      112.5      1.61    195.0    165.0         61.0
# ..    ...    ...        ...       ...      ...      ...          ...
# 962  57.0   male       83.4      1.65    172.0    166.0         67.0
# 966  23.0   male       87.3      1.91    164.0    129.0         58.0
# 968  24.0   male       87.1      1.74    187.0    158.0         67.0
# 971  32.0   male      126.4      1.83    198.0    146.0         62.0
# 972  46.0   male       88.7      1.63    166.0    146.0         66.0
#
#      session_duration_hours  calories_burned workout_type  fat_percentage  \
# ...

# %%
show = df.where((df['calories_burned'] > 1234 ) & (df['workout_type'] == 'hiit') & (df['bmi'] < 60)).dropna(how = 'all')
show
# Out:
#       age  gender  weight_kg  height_m  max_bpm  avg_bpm  resting_bpm  \
# 34   38.0    male       81.4      1.71    187.0    148.0         58.0
# 44   37.0    male      124.2      1.76    168.0    158.0         50.0
# 66   32.0    male       85.9      1.60    176.0    145.0         60.0
# 79   32.0  female       61.7      1.58    183.0    135.0         54.0
# 90   25.0    male       81.5      1.61    170.0    159.0         63.0
# 113  18.0    male       87.6      1.93    161.0    139.0         72.0
# 117  20.0    male       82.7      1.99    179.0    146.0         59.0
# 145  45.0    male       88.5      1.78    198.0    167.0         67.0
# 201  41.0  female       63.4      1.59    162.0    153.0         55.0
# 303  21.0  female       61.3      1.57    191.0    152.0         64.0
# 310  52.0  female       64.9      1.51    164.0    165.0         68.0
# 330  49.0    male       85.0      1.68    197.0    163.0         74.0
# ...

# %%
show = df.where((df['calories_burned'] < 1111) & (df['session_duration_hours'] == 1.5) & (df['water_intake_liters'] > 1.2) ).dropna(how = 'all')
show
# Out:
#       age  gender  weight_kg  height_m  max_bpm  avg_bpm  resting_bpm  \
# 20   19.0    male       89.0      1.77    175.0    127.0         72.0
# 666  52.0  female       52.1      1.67    169.0    124.0         52.0
# 874  43.0  female       40.5      1.74    187.0    143.0         51.0
#
#      session_duration_hours  calories_burned workout_type  fat_percentage  \
# 20                      1.5           1048.0     strength            28.9
# 666                     1.5            837.0         yoga            32.0
# 874                     1.5            965.0         hiit            32.9
#
#      water_intake_liters  workout_frequency_days/week  experience_level    bmi
# 20                   3.7                          4.0               2.0  28.41
# 666                  1.5                          2.0               1.0  18.68
# 874                  2.2                          3.0               2.0  13.38

# %% [markdown]
# ### В рамках бизнес-задачи постройте несколько сводных таблиц

# %%
df.pivot_table(values ='session_duration_hours', index ='workout_type', aggfunc ='mean')
# Out:
#               session_duration_hours
# workout_type
# cardio                      1.220078
# hiit                        1.287059
# strength                    1.260155
# yoga                        1.262845

# %% [markdown]
# Эта таблица показывает сколько в среднем длится каждый тип тренировки

# %%
df.pivot_table(values='calories_burned', index = 'gender', columns = 'workout_type', aggfunc = 'mean')
# Out:
# workout_type      cardio        hiit    strength        yoga
# gender
# female        834.793651  869.953271  863.097561  886.122642
# male          933.077519  978.228070  954.066667  916.789474

# %% [markdown]
# Эта табалица сравнивает эффективность разных тренировок у муж и жен

# %%
df.pivot_table(values='bmi', index= 'experience_level', aggfunc= 'mean')
# Out:
#                         bmi
# experience_level
# 1                 24.624362
# 2                 25.256034
# 3                 24.747592

# %% [markdown]
# Сравнивает ИТМ в зависимости от опыта

# %% [markdown]
# ### 2.5 groupby + agg

# %%
df.groupby('gender').agg({
    'calories_burned':['mean','min','max'],
    'avg_bpm':'mean',
    'water_intake_liters':'mean'
})
# Out:
#        calories_burned                    avg_bpm water_intake_liters
#                   mean    min     max        mean                mean
# gender
# female      862.248918  303.0  1625.0  143.621212            2.205411
# male        944.455969  331.0  1783.0  143.898239            3.007436

# %%
df.groupby('workout_type').agg({
    'session_duration_hours':['mean','min','max'],
    'calories_burned':['mean','max']
})
# Out:
#              session_duration_hours             calories_burned
#                                mean   min   max            mean     max
# workout_type
# cardio                     1.220078  0.51  1.99      884.513725  1625.0
# hiit                       1.287059  0.53  1.99      925.805430  1766.0
# strength                   1.260155  0.51  2.00      910.697674  1783.0
# yoga                       1.262845  0.50  1.99      903.188285  1582.0

# %%
df.groupby('gender').agg({
    'weight_kg':['mean','min','max'],
    'height_m':'mean'
})
# Out:
#         weight_kg               height_m
#              mean   min    max      mean
# gender
# female  60.939827  40.0   79.9  1.644242
# male    85.531115  45.0  129.9  1.793405

# %%
# Пример: зависимость между продолжительностью и калориями
sns.scatterplot(x='session_duration_hours', y='calories_burned', hue='workout_type', data=df)
plt.title('Зависимость калорий от длительности сессии')
plt.show()

# %% [markdown]
# ### Промежуточный вывод 2
# ## В это работе я сделал 3 сводные таблицы по 5 примеров qurey и сгрупировал данные вычислив агригатные функции.
# Изучил метод qurey, groupby + agg и вспомнил loc и iloc

# %% [markdown]
# ## Графический анализ данных

# %% [markdown]
# matplotlib.pyplot три графика

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['age'], bins=10, color='skyblue', edgecolor='black')
plt.title('Распределение по возрасту')
plt.xlabel('Возраст')
plt.ylabel('Количество клиентов')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x='age', y='calories_burned', hue='gender', data=df, palette='coolwarm')
plt.title('Зависимость калорий от возраста')
plt.xlabel('Возраст')
plt.ylabel('Калории')
plt.grid(True)
plt.legend(title='Пол')
plt.show()

# %%
avg_calories = df.groupby('workout_type')['calories_burned'].mean()

plt.figure(figsize=(8, 5))
avg_calories.plot(kind='bar', color='coral', edgecolor='black')
plt.title('Средние калории по типам тренировок')
plt.xlabel('Тип тренировки')
plt.ylabel('Среднее число калорий')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# seaborn as sns два графика

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='gender', y='bmi', data=df, palette='Set2')
plt.title('Распределение BMI по полу')
plt.xlabel('Пол')
plt.ylabel('Индекс массы тела')
plt.grid(True)
plt.show()
# Out:
# /tmp/ipython-input-47-212487748.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='gender', y='bmi', data=df, palette='Set2')

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x='age', y='calories_burned', hue='gender', data=df, palette='coolwarm')
plt.title('Зависимость калорий от возраста')
plt.xlabel('Возраст')
plt.ylabel('Калории')
plt.grid(True)
plt.legend(title='Пол')
plt.show()

# %% [markdown]
# ### 3. Портрет типичного потребителя
# На основе анализа (группировок, диаграмм, статистики):
#
# Возраст: около 38–40 лет.
#
# Пол: чаще мужчины (если преобладают в df['gender']).
#
# Тип тренировки: чаще выбирается «Strength» или «Cardio».
#
# Индекс массы тела (BMI): в пределах нормы, ~24–26.
#
# Уровень опыта: в основном средний (2).
#
# Средняя продолжительность тренировки: около 1.2 часа.
#
# Калории: в среднем сжигается около 900 ккал за сессию.

# %% [markdown]
# ### Выводы и рекомендации
#
# ## ✅ 1. Итоги аналитической работы
#
# * Проведена предобработка данных: устранены пропуски, дубликаты, очищены названия столбцов.
# * Выполнена фильтрация и логическая индексация, анализ распределений и зависимостей между параметрами.
# * Построены сводные таблицы и группировки, выявлены ключевые закономерности.
# * Проведён графический анализ: визуализированы основные метрики и связи.
# * Сформирован портрет типичного пользователя на основе данных.
#
# ---
#
# ## 💡 2. Ответ на бизнес-задачу
#
# Бизнес-задача — понять поведение клиентов, их предпочтения и показатели активности для принятия решений по улучшению услуг.
#
# Решение:
#
# * Да, задача решена: получены полезные сведения о целевой аудитории.
# * Выявлены наиболее популярные типы тренировок, средние значения BMI, возраста, калорий и др.
# * Обнаружены потенциальные сегменты для персонализации предложений.
#
# ---
#
# ## 📌 3. Практические рекомендации
#
# 1. Персонализировать предложения — например, предлагать силовые тренировки клиентам 30–45 лет, т.к. они чаще выбирают этот тип и показывают хорошие результаты.
# 2. Уделить внимание группам с повышенным BMI — можно ввести специальные программы снижения веса.
# 3. Упростить адаптацию новичков — для клиентов с низким опытом организовать вводные занятия и обучение.
#
# ---
#
# ## 🔮 4. Дальнейшие шаги и развитие
#
# * Обучение ML-модели: например, для прогнозирования оттока клиентов или рекомендаций тренировок.
# * Создание интерактивного дашборда (в Power BI, Tableau или Streamlit) для визуального отслеживания метрик.
# * Углублённая кластеризация клиентов (например, с помощью K-Means) для лучшего таргетирования маркетинга.
